# %% [markdown]
# ## Homework-3: MNIST Classification with ConvNet
#
# ### **Deadline: 2021.04.06 23:59:00 **
#
# ### In this homework, you need to
# - #### implement the forward and backward functions for ConvLayer (`layers/conv_layer.py`)
# - #### implement the forward and backward functions for PoolingLayer (`layers/pooling_layer.py`)
# - #### implement the forward and backward functions for DropoutLayer (`layers/dropout_layer.py`)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

from network import Network
from solver import train, test
from plot import plot_loss_and_acc

# %% [markdown]
# ## Load MNIST Dataset
# We use tensorflow tools to load dataset for convenience.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
def decode_image(image):
    # Normalize from [0, 255.] to [0., 1.0], and then subtract by the mean value
    image = tf.cast(image, tf.float32)
    image = tf.reshape(image, [1, 28, 28])
    image = image / 255.0
    image = image - tf.reduce_mean(image)
    return image

def decode_label(label):
    # Encode label with one-hot encoding
    return tf.one_hot(label, depth=10)

# %%
# Data Preprocessing
x_train = tf.data.Dataset.from_tensor_slices(x_train).map(decode_image)
y_train = tf.data.Dataset.from_tensor_slices(y_train).map(decode_label)
data_train = tf.data.Dataset.zip((x_train, y_train))
x_test = tf.data.Dataset.from_tensor_slices(x_test).map(decode_image)
y_test = tf.data.Dataset.from_tensor_slices(y_test).map(decode_label)
data_test = tf.data.Dataset.zip((x_test, y_test))

# %% [markdown]
# ## Set Hyperparameters
# You can modify hyperparameters by yourself.

# %%
batch_size = 100
max_epoch = 10
init_std = 0.01

learning_rate = 0.001
weight_decay = 0.005

disp_freq = 50

# %% [markdown]
# ## Criterion and Optimizer

# %%
from criterion import SoftmaxCrossEntropyLossLayer
from optimizer import SGD

criterion = SoftmaxCrossEntropyLossLayer()
sgd = SGD(learning_rate, weight_decay)

# %% [markdown]
# ## ConvNet

# %%
from layers import FCLayer, ReLULayer, ConvLayer, MaxPoolingLayer, ReshapeLayer

convNet = Network()
convNet.add(ConvLayer(1, 8, 3, 1))
convNet.add(ReLULayer())
convNet.add(MaxPoolingLayer(2, 0))
convNet.add(ConvLayer(8, 16, 3, 1))
convNet.add(ReLULayer())
convNet.add(MaxPoolingLayer(2, 0))
convNet.add(ReshapeLayer((batch_size, 16, 7, 7), (batch_size, 784)))
convNet.add(FCLayer(784, 128))
convNet.add(ReLULayer())
convNet.add(FCLayer(128, 10))
# Out:
# (100, 1, 14, 14)

# %%
# Train
convNet.is_training = True
convNet, conv_loss, conv_acc = train(convNet, criterion, sgd, data_train, max_epoch, batch_size, disp_freq)
# Out:
# WARNING:tensorflow:From c:\Users\Jiawen\OneDrive\2020-2021_Spring\深度学习\homework3\solver.py:15: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# This is a deprecated API that should only be used in TF 1 graph mode and legacy TF 2 graph mode available through `tf.compat.v1`. In all other situations -- namely, eager mode and inside `tf.function` -- you can consume dataset elements using `for elem in dataset: ...` or by explicitly creating iterator via `iterator = iter(dataset)` and fetching its elements via `values = next(iterator)`. Furthermore, this API is not available in TF 2. During the transition from TF 1 to TF 2 you can use `tf.compat.v1.data.make_one_shot_iterator(dataset
# Epoch [8][10]	 Batch [100][550]	 Training Loss 0.0340	 Accuracy 0.9889
# Epoch [8][10]	 Batch [150][550]	 Training Loss 0.0317	 Accuracy 0.9901
# Epoch [8][10]	 Batch [200][550]	 Training Loss 0.0320	 Accuracy 0.9900
# Epoch [8][10]	 Batch [250][550]	 Training Loss 0.0308	 Accuracy 0.9904
# Epoch [8][10]	 Batch [300][550]	 Training Loss 0.0315	 Accuracy 0.9903
# Epoch [8][10]	 Batch [350][550]	 Training Loss 0.0320	 Accuracy 0.9902
# Epoch [8][10]	 Batch [400][550]	 Training Loss 0.0331	 Accuracy 0.9901
# Epoch [8][10]	 Batch [450][550]	 Training Loss 0.0333	 Accuracy 0.9900
# Epoch [8][10]	 Batch [500][550]	 Training Loss 0.0336	 Accuracy 0.9900
#
# Epoch [8]	 Average training loss 0.0336	 Average training accuracy 0.9898
# Epoch [8]	 Average validation loss 0.0686	 Average validation accuracy 0.9802
#
# Epoch [9][10]	 Batch [0][550]	 Training Loss 0.0793	 Accuracy 0.9800
# Epoch [9][10]	 Batch [50][550]	 Training Loss 0.0305	 Accuracy 0.9906
# Epoch [9][10]	 Batch [100][550]	 Training Loss 0.0303	 Accuracy 0.9906
# Epoch [9][10]	 Batch [150][550]	 Training Loss 0.0283	 Accuracy 0.9916
# Epoch [9][10]	 Batch [200][550]	 Training Loss 0.0286	 Accuracy 0.9912
# Epoch [9][10]	 Batch [250][550]	 Training Loss 0.0275	 Accuracy 0.9916
# Epoch [9][10]	 Batch [300][550]	 Training Loss 0.0281	 Accuracy 0.9915
# Epoch [9][10]	 Batch [350][550]	 Training Loss 0.0286	 Accuracy 0.9914
# Epoch [9][10]	 Batch [400][550]	 Training Loss 0.0296	 Accuracy 0.9912
# Epoch [9][10]	 Batch [450][550]	 Training Loss 0.0297	 Accuracy 0.9912
# Epoch [9][10]	 Batch [500][550]	 Training Loss 0.0300	 Accuracy 0.9910
#
# Epoch [9]	 Average training loss 0.0298	 Average training accuracy 0.9909
# Epoch [9]	 Average validation loss 0.0678	 Average validation accuracy 0.9814

# %%
# Test
convNet.is_training = False
test(convNet, criterion, data_test, batch_size, disp_freq)
# Out:
# Testing...
# The test accuracy is 0.9803.

# %% [markdown]
# ## Plot

# %%
plot_loss_and_acc({'ConvNet': [conv_loss, conv_acc]})

# %% [markdown]
# ### ~~You have finished homework3, congratulations!~~
#
# **Next, according to the requirements (4):**
# ### **You need to implement the Dropout layer and train the network again.**

# %%
from layers import DropoutLayer


learning_rate = 0.008
weight_decay = 0.001

# build your network
convNet = Network()
convNet.add(ConvLayer(1, 8, 3, 1))
convNet.add(ReLULayer())
convNet.add(MaxPoolingLayer(2, 0))
convNet.add(ConvLayer(8, 16, 3, 1))
convNet.add(ReLULayer())
convNet.add(MaxPoolingLayer(2, 0))
convNet.add(ReshapeLayer((batch_size, 16, 7, 7), (batch_size, 784)))
convNet.add(FCLayer(784, 128))
convNet.add(DropoutLayer())
convNet.add(ReLULayer())
convNet.add(FCLayer(128, 10))

# %%
# training
convNet.is_training = True
convNet, conv_loss, conv_acc = train(convNet, criterion, sgd, data_train, max_epoch, batch_size, disp_freq)
# Out:
# WARNING:tensorflow:From c:\Users\Jiawen\OneDrive\2020-2021_Spring\深度学习\homework3\solver.py:15: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# This is a deprecated API that should only be used in TF 1 graph mode and legacy TF 2 graph mode available through `tf.compat.v1`. In all other situations -- namely, eager mode and inside `tf.function` -- you can consume dataset elements using `for elem in dataset: ...` or by explicitly creating iterator via `iterator = iter(dataset)` and fetching its elements via `values = next(iterator)`. Furthermore, this API is not available in TF 2. During the transition from TF 1 to TF 2 you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)` to create a TF 1 graph mode style iterator for a dataset created through TF 2 APIs. Note that this should be a transient state of your code base as there are in general no guarantees about the interoperability of TF 1 and TF 2 code.
# Epoch [0][10]	 Batch [0][550]	 Training Loss 6.2911	 Accuracy 0.1300
# Epoch [0][10]	 Batch [50][550]	 Training Loss 1.7369	 Accuracy 0.5592
# Epoch [0][10]	 Batch [100][550]	 Training Loss 1.1523	 Accuracy 0.6917
# Epoch [0][10]	 Batch [150][550]	 Training Loss 0.9100	 Accuracy 0.7499
# Epoch [0][10]	 Batch [200][550]	 Training Loss 0.7673	 Accuracy 0.7863
# Epoch [0][10]	 Batch [250][550]	 Training Loss 0.6695	 Accuracy 0.8115
# Epoch [0][10]	 Batch [300][550]	 Training Loss 0.5992	 Accuracy 0.8298
# Epoch [0][10]	 Batch [350][550]	 Training Loss 0.5440	 Accuracy 0.8443
# Epoch [0][10]	 Batch [400][550]	 Training Loss 0.5030	 Accuracy 0.8558
# Epoch [0][10]	 Batch [450][550]	 Training Loss 0.4676	 Accuracy 0.8654
# Epoch [0][10]	 Batch [500][550]	 Training Loss 0.4406	 Accuracy 0.8725
#
# Epoch [0]	 Average training loss 0.4166	 Average training accuracy 0.8791
# Epoch [0]	 Average validation loss 0.1480	 Average validation accuracy 0.9566
#
# Epoch [1][10]	 Batch [0][550]	 Training Loss 0.1217	 Accuracy 0.9700
# Epoch [1][10]	 Batch [50][550]	 Training Loss 0.1336	 Accuracy 0.9612
# Epoch [1][10]	 Batch [100][550]	 Training Loss 0.1407	 Accuracy 0.9568
# Epoch [1][10]	 Batch [150][550]	 Training Loss 0.1428	 Accuracy 0.9569
# Epoch [1][10]	 Batch [200][550]	 Training Loss 0.1404	 Accuracy 0.9568
# Epoch [1][10]	 Batch [250][550]	 Training Loss 0.1355	 Accuracy 0.9580
# Epoch [1][10]	 Batch [300][550]	 Training Loss 0.1329	 Accuracy 0.9593
# Epoch [1][10]	 Batch [350][550]	 Training Loss 0.1299	 Accuracy 0.9604
# Epoch [1][10]	 Batch [400][550]	 Training Loss 0.1288	 Accuracy 0.9609
# Epoch [1][10]	 Batch [450][550]	 Training Loss 0.1275	 Accuracy 0.9613
# Epoch [1][10]	 Batch [500][550]	 Training Loss 0.1274	 Accuracy 0.9612
#
# Epoch [1]	 Average training loss 0.1263	 Average training accuracy 0.9615
# Epoch [1]	 Average validation loss 0.1013	 Average validation accuracy 0.9724
#
# Epoch [2][10]	 Batch [0][550]	 Training Loss 0.0761	 Accuracy 0.9700
# Epoch [7][10]	 Batch [300][550]	 Training Loss 0.0442	 Accuracy 0.9862
# Epoch [7][10]	 Batch [350][550]	 Training Loss 0.0449	 Accuracy 0.9860
# Epoch [7][10]	 Batch [400][550]	 Training Loss 0.0465	 Accuracy 0.9856
# Epoch [7][10]	 Batch [450][550]	 Training Loss 0.0463	 Accuracy 0.9856
# Epoch [7][10]	 Batch [500][550]	 Training Loss 0.0467	 Accuracy 0.9853
#
# Epoch [7]	 Average training loss 0.0468	 Average training accuracy 0.9853
# Epoch [7]	 Average validation loss 0.0633	 Average validation accuracy 0.9838
#
# Epoch [8][10]	 Batch [0][550]	 Training Loss 0.0576	 Accuracy 0.9900
# Epoch [8][10]	 Batch [50][550]	 Training Loss 0.0418	 Accuracy 0.9878
# Epoch [8][10]	 Batch [100][550]	 Training Loss 0.0422	 Accuracy 0.9874
# Epoch [8][10]	 Batch [150][550]	 Training Loss 0.0415	 Accuracy 0.9872
# Epoch [8][10]	 Batch [200][550]	 Training Loss 0.0406	 Accuracy 0.9876
# Epoch [8][10]	 Batch [250][550]	 Training Loss 0.0397	 Accuracy 0.9880
# Epoch [8][10]	 Batch [300][550]	 Training Loss 0.0408	 Accuracy 0.9879
# Epoch [8][10]	 Batch [350][550]	 Training Loss 0.0413	 Accuracy 0.9872
# Epoch [8][10]	 Batch [400][550]	 Training Loss 0.0421	 Accuracy 0.9871
# Epoch [8][10]	 Batch [450][550]	 Training Loss 0.0421	 Accuracy 0.9869
# Epoch [8][10]	 Batch [500][550]	 Training Loss 0.0423	 Accuracy 0.9869
#
# Epoch [8]	 Average training loss 0.0422	 Average training accuracy 0.9869
# Epoch [8]	 Average validation loss 0.0636	 Average validation accuracy 0.9842
#
# Epoch [9][10]	 Batch [0][550]	 Training Loss 0.1148	 Accuracy 0.9700
# Epoch [9][10]	 Batch [50][550]	 Training Loss 0.0372	 Accuracy 0.9896
# Epoch [9][10]	 Batch [100][550]	 Training Loss 0.0388	 Accuracy 0.9881
# Epoch [9][10]	 Batch [150][550]	 Training Loss 0.0362	 Accuracy 0.9889
# Epoch [9][10]	 Batch [200][550]	 Training Loss 0.0372	 Accuracy 0.9883
# Epoch [9][10]	 Batch [250][550]	 Training Loss 0.0367	 Accuracy 0.9885
# Epoch [9][10]	 Batch [300][550]	 Training Loss 0.0379	 Accuracy 0.9883
# Epoch [9][10]	 Batch [350][550]	 Training Loss 0.0378	 Accuracy 0.9882
# Epoch [9][10]	 Batch [400][550]	 Training Loss 0.0392	 Accuracy 0.9879
# Epoch [9][10]	 Batch [450][550]	 Training Loss 0.0390	 Accuracy 0.9881
# Epoch [9][10]	 Batch [500][550]	 Training Loss 0.0395	 Accuracy 0.9879
#
# Epoch [9]	 Average training loss 0.0397	 Average training accuracy 0.9878
# Epoch [9]	 Average validation loss 0.0611	 Average validation accuracy 0.9844

# %%
# testing
convNet.is_training = False
test(convNet, criterion, data_test, batch_size, disp_freq)
# Out:
# Testing...
# The test accuracy is 0.9874.

# %% [markdown]
# ## Plot

# %%
plot_loss_and_acc({'ConvNet': [conv_loss, conv_acc]})
